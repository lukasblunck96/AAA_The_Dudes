# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import TargetEncoder

# %%
KERNELS = ['linear', 'poly', 'rbf', 'sigmoid']
RESOLUTIONS = ['census', 3, 4, 5, 6, 7, 8, 9]
TARGETS = ['demand_target_bucket_1', 'demand_target_bucket_2', 'demand_target_bucket_6', 'demand_target_bucket_24']

# %%
encoder = TargetEncoder(target_type='continuous', cv=5, smooth='auto')
encoder.fit(df['pickup_loc'].values.reshape(-1,1), df['demand_target_bucket_1'].values.reshape(-1,))
df['pickup_loc'] = encoder.transform(df['pickup_loc'].values.reshape(-1,1))
# df_test['pickup_loc'] = encoder.transform(df_test['pickup_loc'])

# %%
# initialize the encoder
encoder = ce.TargetEncoder(cols=['pickup_loc'])

# fit the encoder using the training data
encoder.fit(df['pickup_loc'], df['demand_target_bucket_2'])
df['pickup_loc'] = encoder.transform(df['pickup_loc'])

# %%
df
# Out:
#                  timestamp   pickup_loc  trip_start_hour  trip_start_month  \
# 0      2017-01-02 00:00:00  2411.295363                0                 1
# 1      2017-01-02 01:00:00  2411.295363                1                 1
# 2      2017-01-02 02:00:00  2411.295363                2                 1
# 3      2017-01-02 03:00:00  2411.295363                3                 1
# 4      2017-01-02 04:00:00  2411.295363                4                 1
# ...                    ...          ...              ...               ...
# 13971  2017-10-19 23:00:00   165.030767               23                10
# 13972  2017-10-20 00:00:00   165.030767                0                10
# 13973  2017-10-20 01:00:00   165.030767                1                10
# 13974  2017-10-20 02:00:00   165.030767                2                10
# 13975  2017-10-20 03:00:00   165.030767                3                10
#
# ...

# %% [markdown]
# ## Identify best Kernel

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Define hyperparameter grid for each kernel
param_grid = [
    {'regressor__kernel': ['linear'], 'regressor__C': [0.1, 1, 10, 100]},
    {'regressor__kernel': ['poly'], 'regressor__C': [0.1, 1, 10, 100], 'regressor__degree': [2, 3, 4], 'regressor__gamma': ['auto', 'scale'], 'regressor__coef0': [0, 1, 2]},
    {'regressor__kernel': ['rbf'], 'regressor__C': [0.1, 1, 10, 100], 'regressor__gamma': ['auto', 'scale']},
    {'regressor__kernel': ['sigmoid'], 'regressor__C': [0.1, 1, 10, 100], 'regressor__gamma': ['auto', 'scale'], 'regressor__coef0': [0, 1, 2]}
]

# Create a pipeline with SVR
pipeline = Pipeline([
    ('regressor', SVR(epsilon=0.1))
])

# Create GridSearchCV object
grid_search = GridSearchCV(pipeline, param_grid, cv=5, verbose=2)

# Perform grid search
grid_search.fit(X_scaled, y)

# %%
# Extract the results
cv_results = grid_search.cv_results_

# Create empty lists to hold the results for each kernel
scores = []

# Iterate over the kernels to find the best score for each
for kernel in KERNELS:
    kernel_mask = [param['regressor__kernel'] == kernel for param in cv_results['params']]
    kernel_scores = cv_results['mean_test_score'][kernel_mask]
    best_kernel_score = max(kernel_scores)
    scores.append(best_kernel_score)

# Plot the results
plt.bar(kernels, scores)
plt.ylabel('Mean Test Score')
plt.xlabel('Kernel')
plt.title('Performance of Best Setup for Each Kernel')
plt.show()
